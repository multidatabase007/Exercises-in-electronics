# %%
pip install matplotlib numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python3.10 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Constants for the cardioid response
omega = np.linspace(0, np.pi, 1000)  # Angular frequency range (0 to pi)
theta = np.pi/3  # Angle of the cardioid pattern (60 degrees)

# Frequency response of the cardioid microphone
H_cardioid = 1 + np.cos(theta) * np.cos(omega)

# Plotting
plt.figure(figsize=(8, 6))
plt.plot(omega, H_cardioid, label='Cardioid Microphone')
plt.xlabel('Angular Frequency (radians)')
plt.ylabel('Frequency Response')
plt.title('Frequency Response of a Cardioid Microphone')
plt.axhline(0, color='black',linewidth=0.5)
plt.axvline(np.pi/2, color='red', linestyle='--', label='Nyquist Frequency')
plt.legend()
plt.grid(True)
plt.show()
